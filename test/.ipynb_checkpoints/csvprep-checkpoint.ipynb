# %%
import config #file with client_id and secret for the Spotify API
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
list_of_playlists=["today's top hits","love", "popular music", "ROCK CLASSICS", "techno", "ALL OUT 2000S", "ALL OUT 80S","Top 50 – Global", 
                "Songs to Sing in the Car", "Rock Mix", "Beast Mode", "runnin mixes", "dance/electronic", 
                "rnb", "italo classics it", "country", "latino", "dancing songs", "jazz", "hip-hop","kids songs", "christmas hits"]
len(list_of_playlists)
# Out:
# 22

# %%
#def function fo extracting tracks from the playlists and place them into list

#function to get playlist_id

def playlist_id(name):
    result=sp.search(q=name,limit=5,type="playlist", market="GB")
    if result["playlists"]["items"]:
        playlist_id=result["playlists"]["items"][0]["id"]
        print(f"ID for {name} is found, ID:{playlist_id}")
        #return playlist_id
        return get_playlist_tracks ("Spotify", playlist_id)
    else:
        print("not found")

#function to get the list of tracks from specific playlist_id    
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return songs_ids(tracks)
       
#function to get a list of songs
def songs_ids(tracks):
    list_song_ids=[]
    for i in tracks:
        list_song_ids.append(i['track']['id'])
    return chunk(list_song_ids)

#function to do the chunk thing
def chunk(list_song_ids):
    chunk_size = 100
    list_chopped = [list_song_ids[i:i+chunk_size] for i in range(0,len(list_song_ids), 100)]
    return get_AF(list_chopped)

#function to get AF    
def get_AF(list_chopped):
    list_af = []
    for i in list_chopped:
        list_af.extend(sp.audio_features(i))
    df=pd.DataFrame(list_af)
    return df

# %%
#test all functions with the 1st playlist
todays_top_hits=playlist_id("today's top hits")
# Out:
# ID for today's top hits is found, ID:37i9dQZF1DXcBWIGoYBM5M

# %%
#creating an empty DF to fill
final_df=pd.DataFrame()

# %%
#running functions for each genre from the list

for playlist in list_of_playlists:
    df_temp=playlist_id(playlist)
    final_df=pd.concat([final_df, df_temp])
# Out:
# ID for today's top hits is found, ID:37i9dQZF1DXcBWIGoYBM5M
# ID for love is found, ID:37i9dQZF1EIcE10fGQVrZK
# ID for popular music is found, ID:31ymdYCITDnZRtkKzP3Itp
# ID for ROCK CLASSICS is found, ID:37i9dQZF1DWXRqgorJj26U
# ID for techno is found, ID:2sKjpFIcxrZJo665zLDHPr
# ID for ALL OUT 2000S is found, ID:37i9dQZF1DX4o1oenSJRJd
# ID for ALL OUT 80S is found, ID:37i9dQZF1DX4UtSsGT1Sbe
# ID for Top 50 – Global is found, ID:37i9dQZEVXbMDoHDwVN2tF
# ID for Songs to Sing in the Car is found, ID:37i9dQZF1DWWMOmoXKqHTD
# ID for Rock Mix is found, ID:37i9dQZF1EQpj7X7UK8OOF
# ID for Beast Mode is found, ID:37i9dQZF1DX76Wlfdnj7AP
# ID for runnin mixes is found, ID:7IRdPr9Mk5fXRrxEcQAuEt
# ID for dance/electronic is found, ID:37i9dQZF1EQp9BVPsNVof1
# ID for rnb is found, ID:37i9dQZF1EQoqCH7BwIYb7
# ID for italo classics it is found, ID:2gBx5F22GfevYp9ts9TGkL
# ID for country is found, ID:37i9dQZF1EQmPV0vrce2QZ
# ID for latino is found, ID:0q1di38xTtJS21GjOtaeNb
# ID for dancing songs is found, ID:2DdAHMsw7PBHtwB2m7IOGg
# ID for jazz is found, ID:37i9dQZF1DXbITWG1ZJKYt
# ID for hip-hop is found, ID:37i9dQZF1EQnqst5TRi17F
# ID for kids songs is found, ID:1ynJ63k9UYnKQWH2Q0KMml
# ID for christmas hits is found, ID:37i9dQZF1DX0Yxoavh5qJV

# %%
#dropping duplicates from the final DF
final_df=final_df.drop_duplicates()

# %%
#ready #checking NAs
print(final_df.isna().sum()>0)

final_df
# Out:
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# type                False
# id                  False
# uri                 False
# track_href          False
# analysis_url        False
# duration_ms         False
# time_signature      False
# dtype: bool
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.788   0.758    1    -6.513     1       0.0505        0.1980
# 1          0.472   0.471   10    -5.692     1       0.0603        0.1510
# 2          0.750   0.733    6    -3.180     0       0.0319        0.2560
# 3          0.943   0.558    2    -4.911     1       0.0568        0.0026
# 4          0.561   0.604    9    -4.409     1       0.0337        0.1990
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.567   0.828   10    -4.513     1       0.0819        0.2100
# 96         0.388   0.145    9   -19.697     0       0.0318        0.9780
# 97         0.296   0.421    7    -8.891     1       0.0285        0.2140
# 98         0.621   0.512   10    -8.577     1       0.0300        0.5180
# 99         0.291   0.233    2   -11.804     1       0.0328        0.8800
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000085    0.1040   0.8230  119.008  audio_features
# 1           0.000000    0.1400   0.2190  105.029  audio_features
# 2           0.000000    0.1140   0.8440  111.018  audio_features
# 3           0.000002    0.0937   0.6060  104.983  audio_features
# 4           0.000019    0.1040   0.2420  159.920  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000000    0.0928   0.8450  170.055  audio_features
# 96          0.000007    0.0997   0.0911   75.474  audio_features
# 97          0.000000    0.2320   0.3350   83.425  audio_features
# 98          0.000000    0.3280   0.3720   99.887  audio_features
# 99          0.000062    0.1020   0.1340  118.776  audio_features
#
#                         id                                   uri  \
# 0   7gaA3wERFkFkgivjwbSvkG  spotify:track:7gaA3wERFkFkgivjwbSvkG
# 1   6tNQ70jh4OwmPGpYy6R2o9  spotify:track:6tNQ70jh4OwmPGpYy6R2o9
# 2   3rUGC1vUpkDG9CZFHMur1t  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3   4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 4   17phhZDn6oGtzMe56NuWvj  spotify:track:17phhZDn6oGtzMe56NuWvj
# ..                     ...                                   ...
# 95  13XMz3rpVYITzjFIsSYlZ1  spotify:track:13XMz3rpVYITzjFIsSYlZ1
# 96  06Pfxmp9TtC2H00apclouT  spotify:track:06Pfxmp9TtC2H00apclouT
# 97  2xGO2UjzxeVQSIkyg98vck  spotify:track:2xGO2UjzxeVQSIkyg98vck
# 98  3RH9idbxUAMcUldet2ormp  spotify:track:3RH9idbxUAMcUldet2ormp
# 99  1rRb8IFx7OYqlZnt6ag7cP  spotify:track:1rRb8IFx7OYqlZnt6ag7cP
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/7gaA3wERFkFk...
# 1   https://api.spotify.com/v1/tracks/6tNQ70jh4Owm...
# 2   https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3   https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 4   https://api.spotify.com/v1/tracks/17phhZDn6oGt...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/13XMz3rpVYIT...
# 96  https://api.spotify.com/v1/tracks/06Pfxmp9TtC2...
# 97  https://api.spotify.com/v1/tracks/2xGO2UjzxeVQ...
# 98  https://api.spotify.com/v1/tracks/3RH9idbxUAMc...
# 99  https://api.spotify.com/v1/tracks/1rRb8IFx7OYq...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/7gaA...       214994
# 1   https://api.spotify.com/v1/audio-analysis/6tNQ...       180304
# 2   https://api.spotify.com/v1/audio-analysis/3rUG...       131872
# 3   https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 4   https://api.spotify.com/v1/audio-analysis/17ph...       210689
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/13XM...       160227
# 96  https://api.spotify.com/v1/audio-analysis/06Pf...       166387
# 97  https://api.spotify.com/v1/audio-analysis/2xGO...       261627
# 98  https://api.spotify.com/v1/audio-analysis/3RH9...       206787
# 99  https://api.spotify.com/v1/audio-analysis/1rRb...       251360
#
#     time_signature
# 0                4
# 1                3
# 2                1
# 3                4
# 4                3
# ..             ...
# 95               4
# 96               3
# 97               5
# 98               4
# 99               3
#
# [1865 rows x 18 columns]

# %%
final_df.to_csv('songs_with_AF.csv', index=False)
