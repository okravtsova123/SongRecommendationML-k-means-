# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import random

# %%
#defining website for web scrapping
url="https://www.billboard.com/charts/hot-100/"
response=requests.get(url)
soup=BeautifulSoup(response.content)

# %%
#creating a list of top-100 songs
list_songs=[]
for song in soup.select("div.chart-results-list h3#title-of-a-story.c-title.a-no-trucate.a-font-primary-bold-s.u-letter-spacing-0021"):
    list_songs.append(song.get_text(strip=True))

# %%
#creating a list of top-100 artists for those songs
list_art=[]
for artist in soup.select("div.chart-results-list span.c-label.a-no-trucate.a-font-primary-s"):
    list_art.append(artist.get_text(strip=True))

# %%
#creating a dataframe
df=pd.DataFrame({"song": list_songs, "artist": list_art})
df['source']='billboard'
df
# Out:
#                  song                       artist     source
# 0         Lovin On Me                  Jack Harlow  billboard
# 1        Lose Control                  Teddy Swims  billboard
# 2    Beautiful Things                 Benson Boone  billboard
# 3        Cruel Summer                 Taylor Swift  billboard
# 4              Snooze                          SZA  billboard
# ..                ...                          ...        ...
# 95           Worth It         Offset & Don Toliver  billboard
# 96  Northern Attitude       Noah Kahan With Hozier  billboard
# 97    Scared To Start              Michael Marcagi  billboard
# 98         First Love  Oscar Ortiz X Edgardo Nunez  billboard
# 99      Where It Ends             Bailey Zimmerman  billboard
#
# [100 rows x 3 columns]

# %%
#webscrapping iTunes
url="https://www.popvortex.com/music/charts/top-100-songs.php"
response=requests.get(url)
soup=BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
#creating a lits of songs

list_songs_itunes=[]
for song in soup.select("cite.title"):
    list_songs_itunes.append(song.get_text(strip=True))

list_songs_itunes
# Out:
# ["TEXAS HOLD 'EM",
#  '16 CARRIAGES',
#  'Yeah! (feat. Lil Jon & Ludacris)',
#  "Don't Let the Old Man In",
#  'U Got It Bad',
#  'Fast Car',
#  'My Boo',
#  'Beautiful Things',
#  'Flowers',
#  'Burn (Confessions Special Edition Version)',
#  'Caught Up',
#  'Lose Control',
#  'Fast Car',
#  'Lovin On Me',
#  'You Make Me Wanna...',
#  'Purple Irises',
#  "Should've Been a Cowboy",
#  "TEXAS HOLD 'EM",
#  'U Remind Me',
#  'Confessions, Pt. II (Confessions Special Edition Version)',
#  'Courtesy of the Red, White and Blue (The Angry American)',
#  'Standing Next to You (USHER Remix)',
#  'Dark Matter',
#  'I Remember Everything (feat. Kacey Musgraves)',
#  'Love In This Club (feat. Young Jeezy)',
#  'Turn Down for What',
#  "U Don't Have to Call",
#  'Selfish',
#  'Nice & Slow',
#  'Turn the Lights Back On',
#  'Made For Me',
#  'As Good As I Once Was',
#  'Dance You Outta My Head',
#  'Omg (feat. will.i.am)',
#  'How Do You Like Me Now?!',
#  'Cruel Summer',
# ...

# %%
#creating a lits of artists

list_artists_itunes=[]
for artist in soup.select("em.artist"):
    list_artists_itunes.append(artist.get_text(strip=True))

list_artists_itunes
# Out:
# ['Beyoncé',
#  'Beyoncé',
#  'USHER',
#  'Toby Keith',
#  'USHER',
#  'Tracy Chapman',
#  'Alicia Keys & USHER',
#  'Benson Boone',
#  'Miley Cyrus',
#  'USHER',
#  'USHER',
#  'Teddy Swims',
#  'Luke Combs',
#  'Jack Harlow',
#  'USHER',
#  'Gwen Stefani & Blake Shelton',
#  'Toby Keith',
#  'Beyoncé',
#  'USHER',
#  'USHER',
#  'Toby Keith',
#  'Jung Kook & USHER',
#  'Pearl Jam',
#  'Zach Bryan',
#  'USHER',
#  'DJ Snake & Lil Jon',
#  'USHER',
#  'Justin Timberlake',
#  'USHER',
#  'Billy Joel',
#  'Muni Long',
#  'Toby Keith',
#  'Cat Janice',
#  'USHER',
#  'Toby Keith',
#  'Taylor Swift',
#  'Jelly Roll',
#  'USHER, Summer Walker & 21 Savage',
#  'Paul Russell',
#  'Forrest Frank',
#  'Taylor Swift',
#  'Luke Combs',
#  'Tyler Braden',
#  'Toby Keith',
#  'Taylor Swift',
#  'Alicia Keys',
#  'Neil Diamond',
#  'Chris Stapleton',
#  'Billie Eilish',
#  'Nate Smith',
#  'Megan Thee Stallion',
#  'Toby Keith',
#  'Taylor Swift',
#  'Tim McGraw',
#  'Toby Keith',
#  'Toby Keith',
# ...

# %%
#creating a list

df1=pd.DataFrame({"song": list_songs_itunes, "artist":list_artists_itunes})
df1['source']='itunes'
df1
# Out:
#                                     song                      artist  source
# 0                         TEXAS HOLD 'EM                     Beyoncé  itunes
# 1                           16 CARRIAGES                     Beyoncé  itunes
# 2       Yeah! (feat. Lil Jon & Ludacris)                       USHER  itunes
# 3               Don't Let the Old Man In                  Toby Keith  itunes
# 4                           U Got It Bad                       USHER  itunes
# ..                                   ...                         ...     ...
# 95                              Let's Go                   Key Glock  itunes
# 96      Love In This Club (Main Version)                       USHER  itunes
# 97                           Confessions                       USHER  itunes
# 98                              CARNIVAL  Kanye West & Ty Dolla $ign  itunes
# 99  Don't Let the Old Man In (Radio Mix)                  Toby Keith  itunes
#
# [100 rows x 3 columns]

# %%
#making lists compatible
df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df1 = df1.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
#concating 2 table and deleting duplicates
df_final=pd.concat([df, df1], axis=0)
df_final=df_final.drop_duplicates(subset=['song']) #no need as we will recdomend a song depending on a source (if it's in iTunes - then something from iTunes)
df_final
# Out:
#                                     song                      artist  \
# 0                            lovin on me                 jack harlow
# 1                           lose control                 teddy swims
# 2                       beautiful things                benson boone
# 3                           cruel summer                taylor swift
# 4                                 snooze                         sza
# ..                                   ...                         ...
# 95                              let's go                   key glock
# 96      love in this club (main version)                       usher
# 97                           confessions                       usher
# 98                              carnival  kanye west & ty dolla $ign
# 99  don't let the old man in (radio mix)                  toby keith
#
#        source
# 0   billboard
# 1   billboard
# 2   billboard
# 3   billboard
# 4   billboard
# ..        ...
# 95     itunes
# ...

# %%
#creating functions for user input and recomendation

def user_input():
    song=input("input your favourite song:")
    print("")
    song=song.lower()
    return recommendation(song, df_final) #clarifying in which list we will be chosing the songs

def recommendation(song, df_to_check):
    i=0
    row_of_song=0
    check=0
    for song_checked in df_to_check['song']:
        if song!=df_to_check.iloc[i]['song']:
            i=i+1
        else:
            check=1
            row_of_song=i
            break
   
    if check==0:
        print("sorry your chosen song is not in my list, please try agan")
        print("")
        return user_input()
    else:
        if df_to_check.iloc[row_of_song]['source']=="billboard":
            print(f"The song you've inputed is in {df_to_check.iloc[row_of_song]['source'].upper()} chart!")
            print("")
            filtered_df=df_to_check[df_to_check['source']==df_to_check.iloc[row_of_song]['source']]
            random_song = random.choice(filtered_df['song'])
            row_w_song=filtered_df[filtered_df['song']==random_song]
            artist=row_w_song['artist'].iloc[0]
            print("You may like another one from the same chart, try this one:", random_song.upper(), "by", artist.upper())
            print("")
            choice=input('Do you want to try again? y/n:')
            if choice.lower()=='y':
                return user_input()
        else:
            print(f"The song you've inputed is not in BILLBOARD chart, but it is in {df_to_check.iloc[row_of_song]['source'].upper()} chart!")
            print("")
            filtered_df=df_to_check[df_to_check['source']==df_to_check.iloc[row_of_song]['source']]
            random_song = random.choice(filtered_df['song'])
            row_w_song=filtered_df[filtered_df['song']==random_song]
            artist=row_w_song['artist'].iloc[0]
            print(f"Try this one (also from {df_to_check.iloc[row_of_song]['source'].upper()} top 100):", random_song.upper(), "by", artist.upper())
            print("")
            choice=input('Do you want to try again? y/n:')
            if choice.lower()=='y':
                return user_input()

# %%
user_input()
# Out:
# input your favourite song:lovin on me
#
# The song you've inputed is in BILLBOARD chart!
#
# You may like another one from the same chart, try this one: STANDING NEXT TO YOU by JUNG KOOK
#
# Do you want to try again? y/n:y
# input your favourite song:snooze
#
# The song you've inputed is in BILLBOARD chart!
#
# You may like another one from the same chart, try this one: MADE FOR ME by MUNI LONG
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 user_input()
#
# Cell In[119], line 7, in user_input()
#       5 print("")
#       6 song=song.lower()
# ----> 7 return recommendation(song, df_final)
#
# Cell In[119], line 37, in recommendation(song, df_to_check)
#      35     choice=input('Do you want to try again? y/n:')
#      36     if choice.lower()=='y':
# ---> 37         return user_input()
#      38 else:
# ...

# %%
#webscrapping TOP-100 from EuropaPlus Moscow
url="https://stations.su/evropa-plus/top"
response=requests.get(url)
soup=BeautifulSoup(response.content)

songs_europaplus=[]
for song in soup.select("p.JoyTypography-root.JoyTypography-body2.JoyTypography-noWrap"):
    songs_europaplus.append(song.get_text())
    
songs_europaplus=songs_europaplus[2:]
songs_europaplus = [songs_europaplus[i] for i in range(len(songs_europaplus)) if i % 2 == 0]

artists_europaplus=[]
for artist in soup.select("p.JoyTypography-root.JoyTypography-body2.JoyTypography-noWrap.css-qfjfoc"):
    artists_europaplus.append(artist.get_text())

artists_europaplus=artists_europaplus[1:]

# %%
#creating a df out of 2 lists
df_EP=pd.DataFrame({"song":songs_europaplus, "artist":artists_europaplus})
df_EP['source']="europalus"

# %%
df_EP
# Out:
#                             song           artist     source
# 0                     ITALODISCO       The Kolors  europalus
# 1               This Is The Life  Sarah De Warren  europalus
# 2                             3D        Jung Kook  europalus
# 3                      yes, and?    Ariana Grande  europalus
# 4         Bécane - A Colors Show             Yamê  europalus
# ..                           ...              ...        ...
# 95          Wide Awake (Red Mix)       Eric Saade  europalus
# 96                          Home   Klangkarussell  europalus
# 97                 Зима в сердце       Моя Мишель  europalus
# 98               I'm Good (Blue)     David Guetta  europalus
# 99  Somebody That I Used To Know            Gotye  europalus
#
# [100 rows x 3 columns]
